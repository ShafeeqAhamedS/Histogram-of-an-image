# %% [markdown]
# # B/W Image

# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread("mikasa_c.png",0)
cv2.imshow("Mikasa",im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hist = cv2.calcHist([im],[0],None,[256],[0,255])

# %%
plt.imshow(im)
plt.show()

# %%
plt.figure()
plt.title("Histogram of B/W Image")
plt.xlabel("GrayScale Values")
plt.ylabel("Pixel Count")
plt.stem(hist)
plt.show()

# %%
equ = cv2.equalizeHist(im)

# %%
cv2.imshow("Mikasa",equ)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hist1 = cv2.calcHist([equ],[0],None,[256],[0,255])

# %%
plt.figure()
plt.title("Histogram of Equalized Image")
plt.xlabel("GrayScale Values")
plt.ylabel("Pixel Count")
plt.stem(hist1)
plt.show()

# %%
plt.imshow(equ)
plt.show()

# %% [markdown]
# # Color Image

# %%
im_c = cv2.imread("mikasa_c.png",1)
cv2.imshow("Mikasa",im_c)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hist = cv2.calcHist([im_c],[1],None,[256],[0,255])

# %%
plt.imshow(im_c)
plt.show()

# %%
plt.figure()
plt.title("Histogram of Colour Image")
plt.xlabel("GrayScale Values")
plt.ylabel("Pixel Count")
plt.stem(hist)
plt.show()

# %%
equ = cv2.equalizeHist(im_c)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 equ = cv2.equalizeHist(im_c)
#
# error: OpenCV(4.6.0) C:\b\abs_74oeeuevib\croots\recipe\opencv-suite_1664548340488\work\modules\imgproc\src\histogram.cpp:3440: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'cv::equalizeHist'

# %%
cv2.imshow("Mikasa",equ)
cv2.waitKey(0)
cv2.destroyAllWindows()
